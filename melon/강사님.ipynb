# %%
import plotly
import pandas as pd
import sys

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
# ...

# %%
top_202101 = pd.read_excel("./data/2021/melon_2021.01.xlsx")
top_202102 = pd.read_excel("./data/2021/melon_2021.02.xlsx")
top_202103 = pd.read_excel("./data/2021/melon_2021.03.xlsx")
top_202104 = pd.read_excel("./data/2021/melon_2021.04.xlsx")
top_202105 = pd.read_excel("./data/2021/melon_2021.05.xlsx")
top_202106 = pd.read_excel("./data/2021/melon_2021.06.xlsx")

# %%
top_202101.head()
# Out:
#    Unnamed: 0                                      제목  \
# 0           0  VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
# 1           1                           밤하늘의 별을(2020)
# 2           2                                Dynamite
# 3           3                               잠이 오질 않네요
# 4           4                          Lovesick Girls
#
#                                                   가수  \
# 0  미란이 (Mirani), 먼치맨(MUNCHMAN), Khundi Panda, 머쉬베...
# 1                                                 경서
# 2                                              방탄소년단
# 3                                                장범준
# 4                                          BLACKPINK
#
#                            앨범         발매일    장르
# 0           쇼미더머니 9 Episode 1  2020.11.21  랩/힙합
# 1               밤하늘의 별을(2020)  2020.11.14   발라드
# 2  Dynamite (DayTime Version)  2020.08.24    댄스
# 3                   잠이 오질 않네요  2020.10.24   발라드
# 4                   THE ALBUM  2020.10.02    댄스

# %%
top_202101['total'] = top_202101.count(axis=1)
top_202101.head()
# Out:
#    Unnamed: 0                                      제목  \
# 0           0  VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
# 1           1                           밤하늘의 별을(2020)
# 2           2                                Dynamite
# 3           3                               잠이 오질 않네요
# 4           4                          Lovesick Girls
#
#                                                   가수  \
# 0  미란이 (Mirani), 먼치맨(MUNCHMAN), Khundi Panda, 머쉬베...
# 1                                                 경서
# 2                                              방탄소년단
# 3                                                장범준
# 4                                          BLACKPINK
#
#                            앨범         발매일    장르  total
# 0           쇼미더머니 9 Episode 1  2020.11.21  랩/힙합      6
# 1               밤하늘의 별을(2020)  2020.11.14   발라드      6
# 2  Dynamite (DayTime Version)  2020.08.24    댄스      6
# 3                   잠이 오질 않네요  2020.10.24   발라드      6
# ...

# %%
import platform

if platform.system()=='Windows':
    plt.rc('font',family= 'Malgun Gothic')

fig = plt.figure(figsize=(31,14))

sns.countplot(x="장르",data=top_202101, palette="Greens_d");

# %%
fig = plt.figure(figsize=(31,14))

plt.subplot(2,1,2)
sns.set_color_codes('pastel')
sns.barplot(data=top_202101 , x='장르', y='total',label='total', alpha=0.5)

plt.subplot(2,1,1)
sns.set_color_codes('muted')
sns.barplot(data=top_202101 , x='장르', y='total',label='total', alpha=0.5)

plt.show()

# %%
top_202101['장르'].iplot(kind='bar')
# Out:
# <div>                            <div id="deb5169a-b19f-4a08-9c2f-561f6ce2d69f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
top_202101=top_202101.groupby(['장르']).count()[['total']]
top_202101
# Out:
#                 total
# 장르
# POP                 3
# R&B/Soul, 인디음악      1
# 댄스                 11
# 랩/힙합               11
# 랩/힙합, 인디음악          1
# 록/메탈                2
# 록/메탈, 국내드라마         2
# 발라드                13
# 발라드, 국내드라마          3
# 발라드, 인디음악           2
# 인디음악, 포크/블루스        1

# %%
top_202101.sort_values(by='total', ascending=False)
# Out:
#                 total
# 장르
# 발라드                13
# 댄스                 11
# 랩/힙합               11
# POP                 3
# 발라드, 국내드라마          3
# 록/메탈                2
# 록/메탈, 국내드라마         2
# 발라드, 인디음악           2
# R&B/Soul, 인디음악      1
# 랩/힙합, 인디음악          1
# 인디음악, 포크/블루스        1

# %% [markdown]
# ### 인덱스를 열로 바꾸기

# %%
top_202101_df = top_202101.rename_axis('장르').reset_index()
top_202101_df
# Out:
#                 장르  total
# 0              POP      3
# 1   R&B/Soul, 인디음악      1
# 2               댄스     11
# 3             랩/힙합     11
# 4       랩/힙합, 인디음악      1
# 5             록/메탈      2
# 6      록/메탈, 국내드라마      2
# 7              발라드     13
# 8       발라드, 국내드라마      3
# 9        발라드, 인디음악      2
# 10    인디음악, 포크/블루스      1

# %%
# top_202101 = top_202101.drop( 'total', axis=1  )
# top_202101.head()
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(31,20))


plt.subplot(2,1,1)
sns.set_color_codes('muted')
sns.barplot(data=top_202101_df , x='장르', y='total', alpha=0.5)
plt.xlabel("장르", size=20)
plt.ylabel("total", size=20)

plt.subplot(2,1,2)
sns.set_color_codes('pastel')
sns.countplot(data=top_202101_df , x='장르', alpha=0.5)
plt.xlabel("장르", size=20)
plt.ylabel("count", size=20)


plt.show()

# %%
plt.hist(top_202101_df.total)
# Out:
# (array([6., 2., 0., 0., 0., 0., 0., 0., 2., 1.]),
#  array([ 1. ,  2.2,  3.4,  4.6,  5.8,  7. ,  8.2,  9.4, 10.6, 11.8, 13. ]),
#  <BarContainer object of 10 artists>)

# %%
top_202101_df
# Out:
#                 장르  total
# 0              POP      3
# 1   R&B/Soul, 인디음악      1
# 2               댄스     11
# 3             랩/힙합     11
# 4       랩/힙합, 인디음악      1
# 5             록/메탈      2
# 6      록/메탈, 국내드라마      2
# 7              발라드     13
# 8       발라드, 국내드라마      3
# 9        발라드, 인디음악      2
# 10    인디음악, 포크/블루스      1

# %%
dat = top_202101_df.sort_values("total",axis=0, ascending=False)
dat.head(15)
# Out:
#                 장르  total
# 7              발라드     13
# 2               댄스     11
# 3             랩/힙합     11
# 0              POP      3
# 8       발라드, 국내드라마      3
# 5             록/메탈      2
# 6      록/메탈, 국내드라마      2
# 9        발라드, 인디음악      2
# 1   R&B/Soul, 인디음악      1
# 4       랩/힙합, 인디음악      1
# 10    인디음악, 포크/블루스      1

# %%
fig = plt.figure(figsize=(31,14))

sns.set_color_codes('muted')
sns.barplot(data=top_202101_df,x="장르", y='total', label='total', alpha=0.5)
plt.legend()
plt.xlabel("장르", size=20)
plt.ylabel("total", size=20)
# Out:
# Text(0, 0.5, 'total')

# %%
top_202101_df['장르'].iplot(kind='bar',title="202101")
# Out:
# <div>                            <div id="a21a488a-aba8-4b51-862b-dd65766d1a90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
top_202101_df['장르'].iplot(kind='bar', barmode='stack', title="202101")
# Out:
# <div>                            <div id="2b84b8bd-5e4b-403d-b10f-063ecddd6d34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
top_202102=top_202101_df.groupby(['장르']).count()
top_202102
# Out:
#                 total
# 장르
# POP                 1
# R&B/Soul, 인디음악      1
# 댄스                  1
# 랩/힙합                1
# 랩/힙합, 인디음악          1
# 록/메탈                1
# 록/메탈, 국내드라마         1
# 발라드                 1
# 발라드, 국내드라마          1
# 발라드, 인디음악           1
# 인디음악, 포크/블루스        1

# %%
top_202105.groupby(['장르']).count()
# Out:
#               Unnamed: 0  제목  가수  앨범  발매일
# 장르
# POP                    4   4   4   4    4
# R&B/Soul               4   4   4   4    4
# 댄스                    15  15  15  15   15
# 랩/힙합                   7   7   7   7    7
# 록/메탈                   3   3   3   3    3
# 록/메탈, 국내드라마            1   1   1   1    1
# 발라드                   12  12  12  12   12
# 발라드, 국내드라마             2   2   2   2    2
# 발라드, 인디음악              1   1   1   1    1
# 인디음악, 포크/블루스           1   1   1   1    1

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
top_202102.shape, top_202102.columns,
# Out:
# ((11, 1), Index(['total'], dtype='object'))

# %%
top_202103
# Out:
#     Unnamed: 0                                            제목  \
# 0            0                                  롤린 (Rollin')
# 1            1                                     Celebrity
# 2            2         LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
# 3            3                                      Dynamite
# 4            4                                 밤하늘의 별을(2020)
# 5            5                             밝게 빛나는 별이 되어 비춰줄게
# 6            6                                 On The Ground
# 7            7                                       내 손을 잡아
# 8            8        VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
# 9            9                                     잠이 오질 않네요
# 10          10                                Lovesick Girls
# 11          11                         취기를 빌려 (취향저격 그녀 X 산들)
# 12          12                 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)
# 13          13                     나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# ...

# %%
fig = make_subplots(rows=3, cols=2, shared_xaxes=True)

# %%
a = go.Bar(x=top_202101_df['장르'], y=top_202101_df['total'])
b = go.Bar(x=top_202101_df['장르'], y=top_202101_df['total'])
c = go.Bar(x=top_202101_df['장르'], y=top_202101_df['total'])
d = go.Bar(x=top_202101_df['장르'], y=top_202101_df['total'])
e = go.Bar(x=top_202101_df['장르'], y=top_202101_df['total'])
f = go.Bar(x=top_202101_df['장르'], y=top_202101_df['total'])

fig.add_trace(a, row=1, col=1)
fig.add_trace(b, row=1, col=2)
fig.add_trace(c, row=2, col=1)
fig.add_trace(d, row=2, col=2)
fig.add_trace(e, row=3, col=1)
fig.add_trace(f, row=3, col=2)
# Out:
# <div>                            <div id="baa0dfb1-2db5-42c8-9c60-796b8788fb28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("baa0dfb1-2db5-42c8-9c60-796b8788fb28")) {                    Plotly.newPlot(                        "baa0dfb1-2db5-42c8-9c60-796b8788fb28",                        [{"type":"bar","x":["POP","R&B/Soul, \uc778\ub514\uc74c\uc545","\ub304\uc2a4","\ub7a9/\ud799\ud569","\ub7a9/\ud799\ud569, \uc778\ub514\uc74c\uc545","\ub85d/\uba54\ud0c8","\ub85d/\uba54\ud0c8, \uad6d\ub0b4\ub4dc\ub77c\ub9c8","\ubc1c\ub77c\ub4dc","\ubc1c\ub77c\ub4dc, \uad6d\ub0b4\ub4dc\ub77c\ub9c8","\ubc1c\ub77c\ub4dc, \uc778\ub514\uc74c\uc545","\uc778\ub514\uc74c\uc545, \ud3ec\ud06c/\ube14\ub8e8\uc2a4"],"xaxis":"x","y":[3,1,11,11,1,2,2,13,3,2,1],"yaxis":"y"},{"type
# ...
